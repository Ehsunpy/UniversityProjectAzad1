# %% [markdown]
# <div dir="rtl" style="background-color: #282c34; padding: 20px; border-radius: 15px; font-family: 'B Nazanin', sans-serif; color: #ffffff;">
#
# <h2 style="color:#61dafb; text-align: center;">📦 نصب کتابخانه‌های مورد نیاز</h2>
# <p style="font-size: 1.2em; line-height: 1.8;">برای اجرای این پروژه، باید کتابخانه‌های زیر را نصب کنید. این کتابخانه‌ها ابزارهای لازم برای کار با تاریخ‌های میلادی، هجری شمسی و هجری قمری، و تبدیل اعداد به حروف را فراهم می‌کنند.</p>
#
# <ol style="font-size: 1.1em;">
#   <li style="margin-bottom: 15px;"><b style="color:#ffd700;">`inflect`</b> 📝:
#    این کتابخانه برای تبدیل اعداد به حروف انگلیسی و دیگر تبدیلات زبانی استفاده می‌شود. برای نصب آن از دستور زیر استفاده کنید:
#    <br><code style="color:#ff79c6; background-color: #44475a; padding: 3px 6px; border-radius: 5px;">pip install inflect</code></li>
#
#   <li style="margin-bottom: 15px;"><b style="color:#ffd700;">`persiantools`</b> 📅:
#    این کتابخانه برای کار با تاریخ‌های هجری شمسی (جلالی) و ابزارهای مربوط به زبان فارسی استفاده می‌شود. برای نصب آن از دستور زیر استفاده کنید:
#    <br><code style="color:#ff79c6; background-color: #44475a; padding: 3px 6px; border-radius: 5px;">pip install persiantools</code></li>
#
#   <li style="margin-bottom: 15px;"><b style="color:#ffd700;">`hijri-converter`</b> 🌙:
#    این کتابخانه برای تبدیل تاریخ‌های هجری قمری به میلادی و برعکس استفاده می‌شود. برای نصب آن از دستور زیر استفاده کنید:
#    <br><code style="color:#ff79c6; background-color: #44475a; padding: 3px 6px; border-radius: 5px;">pip install hijri-converter</code></li>
# </ol>
#
# <div style="background-color: rgba(255, 255, 255, 0.1); padding: 15px; border-radius: 10px; border-left: 5px solid #61dafb; margin-top: 20px;">
#   💡 <b style="color:#ffdf00;">نکته:</b>
#   شما می‌توانید تمام این کتابخانه‌ها را به صورت یکجا با دستور زیر نصب کنید:
#   <br><code style="color:#ff79c6; background-color: #44475a; padding: 3px 6px; border-radius: 5px;">pip install inflect persiantools hijri-converter</code>
# </div>
#
# </div>

# %%
# !pip install hijri-converter

# %%
# !pip install inflect

# %%
# !pip install persiantools

# %% [markdown]
# <div dir="rtl" style="background-image: url('URL_TO_YOUR_IMAGE'); background-size: cover; padding: 20px; border-radius: 15px; font-family: 'B Nazanin', sans-serif; color: #ffffff;">
#
# <h2 style="color:#fff; text-align: center;">📄 بخش ایمپورت‌ها</h2>
# <p style="font-size: 1.1em; line-height: 1.6;">در این بخش، کتابخانه‌های مورد نیاز برای اجرای کد ایمپورت می‌شوند:</p>
#
# <ol>
#   <li style="margin-bottom: 10px;"><b style="color:#ffd700;">`inflect`</b> 📝:
#    این کتابخانه برای تبدیل اعداد به حروف (مانند تبدیل ۱ به "یک") و دیگر تبدیلات زبانی استفاده می‌شود.</li>
#
#   <li style="margin-bottom: 10px;"><b style="color:#ffd700;">`time`</b> ⏰:
#    این ماژول توابعی برای کار با زمان و کنترل تأخیرها (مانند <code>sleep</code>) ارائه می‌دهد.</li>
#
#   <li style="margin-bottom: 10px;"><b style="color:#ffd700;">`datetime`</b> 📅:
#    این کتابخانه شامل اشیاء و توابعی برای کار با تاریخ و زمان است.
#    <ul style="margin-top: 5px;">
#      <li>از <code style="color:#ff69b4;">date</code> و <code style="color:#ff69b4;">datetime</code> برای ایجاد و دستکاری تاریخ و زمان استفاده می‌شود.</li>
#    </ul>
#   </li>
#
#   <li style="margin-bottom: 10px;"><b style="color:#ffd700;">`sys`</b> 🛠️:
#    این ماژول دسترسی به برخی از متغیرها و توابع مربوط به مفسر پایتون را فراهم می‌کند. برای مدیریت استثناها و دسترسی به آرگومان‌های خط فرمان کاربرد دارد.</li>
# </ol>
#
# <div style="background-color: rgba(0, 0, 0, 0.5); padding: 15px; border-radius: 10px; border-left: 5px solid #ffd700; margin-top: 20px;">
#   💡 <b style="color:#ffdf00;">نکته:</b>
#   این ایمپورت‌ها بستگی به قابلیت‌ها و نیازمندی‌های برنامه دارند. اگر ماژول‌ها نیاز نبودند، می‌توانند حذف شوند تا حافظه کمتری مصرف شود.
# </div>
#
# </div>
#
# ![Age-Calculator-in-Python-840x400.png](data:image/png;base64,...)

# %%
import inflect
import time
from datetime import date, datetime # Import the datetime object
import sys

# %% [markdown]
# <div dir="rtl" style="background-color: #f0f4f8; padding: 20px; border-radius: 15px; font-family: 'B Nazanin', sans-serif; color: #333333;"> <h2 style="color:#007bff; text-align: center;">📅 تابع `user()`</h2> <p style="font-size: 1.1em; line-height: 1.6;"> این تابع برای دریافت تاریخ تولد از کاربر و تعیین نوع تقویم (میلادی، هجری شمسی یا هجری قمری) طراحی شده است. </p> <h4 style="color:#28a745;">🔍 عملکرد:</h4> <ul style="font-size: 1.1em;"> <li><b>درخواست نوع تقویم:</b> کاربر باید یکی از گزینه‌های <code>Gregorian</code> (میلادی)، <code>Islamic</code> (هجری قمری) یا <code>Jalali</code> (هجری شمسی) را انتخاب کند.</li> <li><b>دریافت تاریخ تولد:</b> تاریخ تولد به فرمت <code>YYYY/MM/DD</code> از کاربر دریافت می‌شود.</li> <li><b>تبدیل تاریخ:</b> بر اساس نوع تقویم انتخاب‌شده، تاریخ تولد به تاریخ میلادی تبدیل می‌شود.</li> <li><b>مدیریت خطا:</b> اگر تاریخ یا فرمت ورودی نادرست باشد، پیام خطا نمایش داده می‌شود و تابع دوباره از کاربر ورودی می‌پرسد.</li> </ul> <h4 style="color:#dc3545;">⚠️ نکته:</h4> <p style="font-size: 1.1em;"> تابع به طور مداوم از کاربر ورودی می‌گیرد تا زمانی که تاریخ صحیح و معتبر دریافت کند. </p> </div>

# %%
def user():
    while True:
        try:
            calendar_type = input("Please select the calendar type (Gregorian/Islamic/Jalali): ").strip().lower()
            user_input = input("Date of Birth (format: YYYY/MM/DD): ").strip()

            if calendar_type == "gregorian":
                x = datetime.strptime(user_input, "%Y/%m/%d").date()
            elif calendar_type == "jalali":
                # Convert Jalali to Gregorian
                x = JalaliDate(*map(int, user_input.split('/'))).to_gregorian()
            elif calendar_type == "islamic":
                # Convert Hijri (Islamic) to Gregorian
                hijri_date = Hijri(*map(int, user_input.split('/')))
                x = hijri_date.to_gregorian()
            else:
                print("Invalid calendar type")
                continue

            return x
        except (ValueError, TypeError):
            print('Invalid date or format')
            pass

# %% [markdown]
# <div dir="rtl" style="background-color: #e9f5f9; padding: 20px; border-radius: 15px; font-family: 'B Nazanin', sans-serif; color: #333333;"> <h2 style="color:#007bff; text-align: center;">⏰ تابع `data()`</h2> <p style="font-size: 1.1em; line-height: 1.6;"> این تابع برای محاسبه و نمایش مدت زمانی که از تاریخ تولد تا امروز باقی مانده است، به دقیقه می‌باشد. </p> <h4 style="color:#28a745;">🔍 عملکرد:</h4> <ul style="font-size: 1.1em;"> <li><b>دریافت تاریخ تولد:</b> تابع <code>user()</code> برای دریافت تاریخ تولد از کاربر فراخوانی می‌شود.</li> <li><b>محاسبه تاریخ امروز:</b> تاریخ فعلی سیستم به دست می‌آید.</li> <li><b>محاسبه فاصله زمانی:</b> فاصله زمانی بین تاریخ تولد و تاریخ امروز به صورت <code>timedelta</code> محاسبه می‌شود.</li> <li><b>تبدیل فاصله زمانی به دقیقه:</b> فاصله زمانی به دقیقه تبدیل می‌شود.</li> <li><b>تبدیل به کلمات:</b> تعداد دقیقه‌ها به فرمت کلمات (مثلاً "هزار دقیقه") تبدیل می‌شود.</li> <li><b>نمایش نتیجه:</b> نتیجه به صورت متنی در کنسول نمایش داده می‌شود.</li> </ul> <h4 style="color:#dc3545;">⚠️ نکته:</h4> <p style="font-size: 1.1em;"> در این تابع، فاصله زمانی به دقیقه محاسبه و به کلمات تبدیل می‌شود تا کاربر به راحتی مدت زمان باقی‌مانده را مشاهده کند. </p> </div>

# %%
def data():
    x = user()
    today = date.today()
    my_birthday = x
    time_to_birthday = abs(my_birthday - today)

    minutes_to_birthday = time_to_birthday.days * 24 * 60
    t = p.number_to_words(minutes_to_birthday, andword="")
    print(f"{t.capitalize()} minutes")

# %% [markdown]
# <div dir="rtl" style="background-color: #f4f7f9; padding: 20px; border-radius: 15px; font-family: 'B Nazanin', sans-serif; color: #333333;"> <h2 style="color:#007bff; text-align: center;">🔧 تابع `main()`</h2> <p style="font-size: 1.1em; line-height: 1.6;"> این تابع نقطه ورودی برنامه است و وظیفه اجرای تابع <code>data()</code> را بر عهده دارد. </p> <h4 style="color:#28a745;">🔍 عملکرد:</h4> <ul style="font-size: 1.1em;"> <li><b>فراخوانی تابع <code>data()</code>:</b> تابع <code>data()</code> که وظیفه محاسبه و نمایش مدت زمان باقی‌مانده از تاریخ تولد تا امروز را دارد، فراخوانی می‌شود.</li> </ul> <h4 style="color:#dc3545;">⚠️ نکته:</h4> <p style="font-size: 1.1em;"> تابع <code>main()</code> به عنوان نقطه شروع برنامه، تضمین می‌کند که تمامی مراحل لازم برای محاسبه و نمایش نتیجه به درستی اجرا شوند. </p> </div>

# %%
def main():
    data()

# %% [markdown]
# <div dir="rtl" style="background-color: #f9f9f9; padding: 20px; border-radius: 15px; font-family: 'B Nazanin', sans-serif; color: #333333;"> <h2 style="color:#007bff; text-align: center;">🚀 تابع `main()`</h2> <p style="font-size: 1.1em; line-height: 1.6;"> تابع <code>main()</code> نقطه شروع برنامه است و به عنوان ورودی اولیه، عملیات‌های اصلی برنامه را مدیریت می‌کند. این تابع به سادگی برای اجرای سایر توابع برنامه استفاده می‌شود. </p> <h4 style="color:#28a745;">🔍 عملکرد:</h4> <ul style="font-size: 1.1em;"> <li><b>فراخوانی تابع <code>data()</code>:</b> تابع <code>data()</code> برای پردازش و محاسبه مدت زمان باقی‌مانده تا تاریخ تولد کاربر و نمایش آن به صورت دقیقه‌ای، فراخوانی می‌شود.</li> </ul> <h4 style="color:#dc3545;">⚠️ نکته:</h4> <p style="font-size: 1.1em;"> تابع <code>main()</code> در صورتی که به عنوان نقطه شروع برنامه مشخص شود، به اجرای تابع <code>data()</code> می‌پردازد و برنامه را راه‌اندازی می‌کند. </p> </div>

# %%
main()

# %% [markdown]
# <div dir="rtl" style="background-color: #f2f4f8; padding: 20px; border-radius: 15px; font-family: 'B Nazanin', sans-serif; color: #333333;"> <h1 style="color:#007bff; text-align: center;">🎉 نتیجه برنامه</h1> <p style="font-size: 1.2em; line-height: 1.6; text-align: center;"> با استفاده از این برنامه، می‌توانید مدت زمان باقی‌مانده تا تاریخ تولد خود را به دقیقه محاسبه کرده و به صورت متنی مشاهده کنید. 🤓 </p> <h3 style="color:#28a745; text-align: center;">📜 خروجی نمونه:</h3> <p style="font-size: 1.2em; line-height: 1.6; text-align: center;"> <input type="text" style="font-size: 1.2em; font-family: monospace; border: none; background-color: #e9ecef; padding: 10px; border-radius: 5px;" value="Thirty-three million, six hundred twelve thousand, four hundred eighty minutes" readonly> </p> <h4 style="color:#dc3545; text-align: center;">⚠️ نکات مهم:</h4> <ul style="font-size: 1.1em; line-height: 1.6; text-align: center;"> <li><b>نوع تقویم:</b> نوع تقویم (میلادی، هجری شمسی، هجری قمری) باید به درستی انتخاب شود.</li> <li><b>فرمت تاریخ:</b> تاریخ تولد باید به فرمت <code>YYYY/MM/DD</code> وارد شود.</li> <li><b>دقت:</b> توجه داشته باشید که تمامی محاسبات به صورت دقیقه‌ای انجام می‌شود.</li> </ul> <h3 style="color:#007bff; text-align: center;">🎬 پیش‌نمایش:</h3> <p style="text-align: center;"> <img src="https://media.giphy.com/media/3o7aD4j2yDGAAYP6Te/giphy.gif" alt="Confetti Celebration" style="width: 100px; height: 100px;"/> </p> <h4 style="color:#28a745; text-align: center;">🔗 منابع:</h4> <ul style="font-size: 1.1em; line-height: 1.6; text-align: center;"> <li><a href="https://pypi.org/project/inflect/" style="color: #007bff;">📘 inflect</a></li> <li><a href="https://github.com/persiantools/persiantools" style="color: #007bff;">📘 persiantools</a></li> <li><a href="https://pypi.org/project/hijri-converter/" style="color: #007bff;">📘 hijri-converter</a></li> </ul> </div>
